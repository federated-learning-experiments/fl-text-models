# %% [markdown]
# # Plot Variance Explained by Number of Principle Components for Various Word Embeddings

# %%
import os, sys, io
sys.path.append(os.path.dirname(os.getcwd()))

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from src import dataset, embeddings

# %% [markdown]
# ### Retrieve Stack Overflow Vocab

# %%
vocab = dataset.get_vocab(vocab_size=10000)

# %% [markdown]
# ### GloVe Embeddings

# %%
embedding_path = '../word_embeddings/glove/glove.6B.{}d.txt'.format(300)
word2embedding = embeddings.load_embeddings(embedding_path)
embeddings.plot_pca_variance_explained(word2embedding, vocab)

# %% [markdown]
# ### FastText Embeddings

# %%
embedding_path = '../word_embeddings/fasttext/wiki-news-{}d-1M.vec'.format(300)
word2embedding = embeddings.load_embeddings(embedding_path)
embeddings.plot_pca_variance_explained(word2embedding, vocab)

# %% [markdown]
# ### GPT2 Embeddings

# %%
word2embedding = embeddings.create_gpt_embeddings(vocab)
embeddings.plot_pca_variance_explained(word2embedding, vocab)
